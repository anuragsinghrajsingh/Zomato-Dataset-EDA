# %% [markdown]
# # importing dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/Users/anura/Downloads/Zomatodataset/zomato.csv",encoding = 'latin-1')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # checking dataset

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.size
# Out:
# 200571

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
[fea for fea in df.columns if df[fea].isnull().sum()>0]
# Out:
# ['Cuisines']

# %% [markdown]
# # only Cuisines has 9 missing value

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,6)

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
df1 = pd.read_excel("C:/Users/anura/Downloads/Zomatodataset/Country-Code.xlsx")
df1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
dff = pd.merge(df, df1, on='Country Code', how = 'left')

# %%
dff.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
country = dff.Country.value_counts()
country
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_name = dff.Country.value_counts().index
country_name
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_values = dff.Country.value_counts().values
country_values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
plt.pie(country_values[:3],labels=country_name[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d833a8ab90>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [raw]
# Zomato Maximum transaction/order/records are from India, after that USA and then from UK.

# %%
rating1 = dff[['Aggregate rating','Rating color','Rating text']].value_counts(sort=False).reset_index().rename(columns={0:"Rating Count"})
rating1
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
rating = dff.groupby(['Aggregate rating','Rating color','Rating text'])
rating = rating.size().reset_index().rename(columns={0:"Rating Count"})
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [raw]
# 1) When rating is between 4.5 to 4.9 ----> Excellent
# 2) When rating is between 4.0 to 4.4 ----> Very Good
# 3) When rating is between 3.5 to 3.9 ----> Good
# 4) When rating is between 2.5 to 3.4 ----> Average
# 5) When rating is between 1.8 to 2.4 ----> Poor
# 6) When rating is between  ----> Not Rated

# %%
sns.barplot(x="Aggregate rating", y="Rating Count", data=rating)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [raw]
# 1) Not rated record is very high.
# 2) Maximum no. of record is lies between 2.5 to 4.0.
# 3) As we know that the maximum no. of record are lies between 2.5 to 4.0 then the missing value can be filled by 'Median/Mean' of the given data.
# 4) 'Mean' can be used to fill the missing value because data is not highly skewed.
# 5) For accurate and well approached result then we can use 'Median' or 'MAD' (Median Absolute Deviation) to fill the missing value.
# 6) If missing value is very few then 'Mode' can be also a good option to fill it.

# %% [markdown]
# # Find the Countries name that has given 0 ratings

# %%
zero_rating_country = dff[['Country']][dff['Aggregate rating'] == 0.0].value_counts().reset_index().rename(columns={0:'Total count'})
zero_rating_country
# Out:
#           Country  Total count
# 0           India         2139
# 1          Brazil            5
# 2   United States            3
# 3  United Kingdom            1

# %%
zero_rating_country1 = dff[['Country']][dff['Rating color'] == 'White'].value_counts().reset_index().rename(columns={0:'Total count'})
zero_rating_country1
# Out:
#           Country  Total count
# 0           India         2139
# 1          Brazil            5
# 2   United States            3
# 3  United Kingdom            1

# %%
zero_rating_country2 = dff[['Country']][dff['Rating text'] == 'Not rated'].value_counts().reset_index().rename(columns={0:'Total count'})
zero_rating_country2
# Out:
#           Country  Total count
# 0           India         2139
# 1          Brazil            5
# 2   United States            3
# 3  United Kingdom            1

# %%
zero_rating_country3 = dff[dff['Aggregate rating'] == 0.0].groupby('Country').size().reset_index()
zero_rating_country3.rename(columns={0:'Total count'},inplace=True)
zero_rating_country3
# Out:
#           Country  Total count
# 0          Brazil            5
# 1           India         2139
# 2  United Kingdom            1
# 3   United States            3

# %%
zero_rating_country4 = dff[dff['Rating color'] == 'White'].groupby('Country').size().reset_index()
zero_rating_country4.rename(columns={0:'Total count'},inplace=True)
zero_rating_country4
# Out:
#           Country  Total count
# 0          Brazil            5
# 1           India         2139
# 2  United Kingdom            1
# 3   United States            3

# %%
zero_rating_country5 = dff[dff['Rating text'] == 'Not rated'].groupby('Country').size().reset_index()
zero_rating_country5.rename(columns={0:'Total count'},inplace=True)
zero_rating_country5
# Out:
#           Country  Total count
# 0          Brazil            5
# 1           India         2139
# 2  United Kingdom            1
# 3   United States            3

# %%
dff.groupby(['Aggregate rating','Country']).size().reset_index().head(4)
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [raw]
# Maximum no. of 0 rating is from Indian customers, also other countries 0 rating are quite low but it can be because other countries order as comparatively very low as comapred to India.

# %% [markdown]
# # Find out which currency is used by which country

# %%
dff.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
currency = dff[['Country','Currency']].value_counts().reset_index().rename(columns={0:'Total Count'})
currency
# Out:
#            Country                Currency  Total Count
# 0            India      Indian Rupees(Rs.)         8652
# 1    United States               Dollar($)          434
# 2   United Kingdom              Pounds(£)           80
# 3           Brazil      Brazilian Real(R$)           60
# 4     South Africa                 Rand(R)           60
# 5              UAE      Emirati Diram(AED)           60
# 6      New Zealand           NewZealand($)           40
# 7           Turkey        Turkish Lira(TL)           34
# 8        Australia               Dollar($)           24
# 9      Phillipines        Botswana Pula(P)           22
# 10       Indonesia  Indonesian Rupiah(IDR)           21
# 11           Qatar         Qatari Rial(QR)           20
# 12       Singapore               Dollar($)           20
# 13       Sri Lanka   Sri Lankan Rupee(LKR)           20
# 14          Canada               Dollar($)            4

# %%
currency_index = dff[['Country','Currency']].value_counts().index
currency_index
# Out:
# MultiIndex([(         'India',     'Indian Rupees(Rs.)'),
#             ( 'United States',              'Dollar($)'),
#             ('United Kingdom',             'Pounds(£)'),
#             (        'Brazil',     'Brazilian Real(R$)'),
#             (  'South Africa',                'Rand(R)'),
#             (           'UAE',     'Emirati Diram(AED)'),
#             (   'New Zealand',          'NewZealand($)'),
#             (        'Turkey',       'Turkish Lira(TL)'),
#             (     'Australia',              'Dollar($)'),
#             (   'Phillipines',       'Botswana Pula(P)'),
#             (     'Indonesia', 'Indonesian Rupiah(IDR)'),
#             (         'Qatar',        'Qatari Rial(QR)'),
#             (     'Singapore',              'Dollar($)'),
#             (     'Sri Lanka',  'Sri Lankan Rupee(LKR)'),
#             (        'Canada',              'Dollar($)')],
#            names=['Country', 'Currency'])

# %%
currency1 = dff.groupby(['Country','Currency']).size().reset_index()
currency1.rename(columns={0:'Total Count'},inplace=True)
currency1
# Out:
#            Country                Currency  Total Count
# 0        Australia               Dollar($)           24
# 1           Brazil      Brazilian Real(R$)           60
# 2           Canada               Dollar($)            4
# 3            India      Indian Rupees(Rs.)         8652
# 4        Indonesia  Indonesian Rupiah(IDR)           21
# 5      New Zealand           NewZealand($)           40
# 6      Phillipines        Botswana Pula(P)           22
# 7            Qatar         Qatari Rial(QR)           20
# 8        Singapore               Dollar($)           20
# 9     South Africa                 Rand(R)           60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)           20
# 11          Turkey        Turkish Lira(TL)           34
# 12             UAE      Emirati Diram(AED)           60
# 13  United Kingdom              Pounds(£)           80
# 14   United States               Dollar($)          434

# %%
currency_indexx = dff.groupby(['Country','Currency'])
for i,j in currency_indexx:
    print(i)
# Out:
# ('Australia', 'Dollar($)')
# ('Brazil', 'Brazilian Real(R$)')
# ('Canada', 'Dollar($)')
# ('India', 'Indian Rupees(Rs.)')
# ('Indonesia', 'Indonesian Rupiah(IDR)')
# ('New Zealand', 'NewZealand($)')
# ('Phillipines', 'Botswana Pula(P)')
# ('Qatar', 'Qatari Rial(QR)')
# ('Singapore', 'Dollar($)')
# ('South Africa', 'Rand(R)')
# ('Sri Lanka', 'Sri Lankan Rupee(LKR)')
# ('Turkey', 'Turkish Lira(TL)')
# ('UAE', 'Emirati Diram(AED)')
# ('United Kingdom', 'Pounds(\x8c£)')
# ('United States', 'Dollar($)')

# %%
currency1 = dff.groupby(['Country','Currency'])
currency1.get_group(('India', 'Indian Rupees(Rs.)')).Country.size
# Out:
# 8652

# %% [markdown]
# #  Find out the countries which have online deliveries

# %%
dff.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
onl_del = dff[dff['Has Online delivery'] == 'Yes'].Country.value_counts().reset_index().rename(columns={'Country':"Total Counts",'index':'Country'})
onl_del
# Out:
#   Country  Total Counts
# 0   India          2423
# 1     UAE            28

# %%
uu = dff[dff['Has Online delivery'] == 'Yes'][['Country']].value_counts().reset_index().rename(columns={0:"Total Counts"})
uu
# Out:
#   Country  Total Counts
# 0   India          2423
# 1     UAE            28

# %%
yy = dff[['Has Online delivery']].value_counts().reset_index().rename(columns={0:"Total Counts"})
yy
# Out:
#   Has Online delivery  Total Counts
# 0                  No          7100
# 1                 Yes          2451

# %%
onl_del1 = dff[['Country']][dff['Has Online delivery'] == 'Yes'].value_counts().reset_index().rename(columns={0:"Total Counts"})
onl_del1
# Out:
#   Country  Total Counts
# 0   India          2423
# 1     UAE            28

# %%
onl_del2 = dff[['Country','Has Online delivery']].value_counts().reset_index().rename(columns={0:"Total Counts"})
onl_del2
# Out:
#            Country Has Online delivery  Total Counts
# 0            India                  No          6229
# 1            India                 Yes          2423
# 2    United States                  No           434
# 3   United Kingdom                  No            80
# 4     South Africa                  No            60
# 5           Brazil                  No            60
# 6      New Zealand                  No            40
# 7           Turkey                  No            34
# 8              UAE                  No            32
# 9              UAE                 Yes            28
# 10       Australia                  No            24
# 11     Phillipines                  No            22
# 12       Indonesia                  No            21
# 13       Sri Lanka                  No            20
# 14       Singapore                  No            20
# 15           Qatar                  No            20
# 16          Canada                  No             4

# %%
dff.groupby(['Has Online delivery']).size().reset_index().rename(columns={0:"Total Counts"})
# Out:
#   Has Online delivery  Total Counts
# 0                  No          7100
# 1                 Yes          2451

# %%
dff.groupby(['Country', 'Has Online delivery']).size().reset_index().rename(columns={0:"Total Counts"})
# Out:
#            Country Has Online delivery  Total Counts
# 0        Australia                  No            24
# 1           Brazil                  No            60
# 2           Canada                  No             4
# 3            India                  No          6229
# 4            India                 Yes          2423
# 5        Indonesia                  No            21
# 6      New Zealand                  No            40
# 7      Phillipines                  No            22
# 8            Qatar                  No            20
# 9        Singapore                  No            20
# 10    South Africa                  No            60
# 11       Sri Lanka                  No            20
# 12          Turkey                  No            34
# 13             UAE                  No            32
# 14             UAE                 Yes            28
# 15  United Kingdom                  No            80
# 16   United States                  No           434

# %%
dff[dff['Has Online delivery'] == 'Yes'].groupby('Country').size().reset_index().rename(columns={0:"Total Counts"})
# Out:
#   Country  Total Counts
# 0   India          2423
# 1     UAE            28

# %%
dff[dff['Has Online delivery'] == 'Yes'].groupby(['Country']).size().reset_index().rename(columns={0:"Total Counts"})
# Out:
#   Country  Total Counts
# 0   India          2423
# 1     UAE            28

# %%
dff[dff['Has Online delivery'] == 'Yes'].groupby(dff['Country']).size().reset_index().rename(columns={0:"Total Counts"})
# Out:
#   Country  Total Counts
# 0   India          2423
# 1     UAE            28

# %% [raw]
# Online Delivery is only available in India and UAE.
# Also in some part of India and UAE online delivery is not available.

# %%
#Testing code

dff.Cuisines.isnull().value_counts()
# Out:
# False    9542
# True        9
# Name: Cuisines, dtype: int64

# %%
#Testing code

dff.Cuisines.size
# Out:
# 9551

# %% [markdown]
# # Create a pie chart for Top 5 "Cities Distributions"

# %%
dff.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
dff.groupby('City').size().reset_index().rename(columns={0:"Total Count"})
# Out:
#                 City  Total Count
# 0          Abu Dhabi           20
# 1               Agra           20
# 2          Ahmedabad           21
# 3             Albany           20
# 4          Allahabad           20
# ..               ...          ...
# 136          Weirton            1
# 137  Wellington City           20
# 138   Winchester Bay            1
# 139          Yorkton            1
# 140        ÛÁstanbul           14
#
# [141 rows x 2 columns]

# %% [raw]
# The above method display the datas in asceding order by "Group(City)" not by "value(Total Count)".

# %%
dff.groupby('City').size().reset_index().rename(columns={0:"Total Count"}).sort_values("Total Count",ascending=False)
# Out:
#             City  Total Count
# 88     New Delhi         5473
# 50       Gurgaon         1118
# 89         Noida         1080
# 43     Faridabad          251
# 48     Ghaziabad           25
# ..           ...          ...
# 37   Dicky Beach            1
# 68          Lorn            1
# 107  Quezon City            1
# 66       Lincoln            1
# 65      Lakeview            1
#
# [141 rows x 2 columns]

# %% [raw]
# The above statement sort the datas in descending order by "Total Count" column.

# %%
dff.groupby(['City']).size().reset_index().rename(columns={0:"Total Count"}).sort_values("Total Count",ascending=False).reset_index()
# Out:
#      index         City  Total Count
# 0       88    New Delhi         5473
# 1       50      Gurgaon         1118
# 2       89        Noida         1080
# 3       43    Faridabad          251
# 4       48    Ghaziabad           25
# ..     ...          ...          ...
# 136     37  Dicky Beach            1
# 137     68         Lorn            1
# 138    107  Quezon City            1
# 139     66      Lincoln            1
# 140     65     Lakeview            1
#
# [141 rows x 3 columns]

# %% [raw]
# Here again "reset_index()" method has been used to re-order the index because sorting the dataset results in alter in the index.

# %%
cityy_name = dff.groupby(['City']).size().reset_index().rename(columns={0:"Total Count"}).sort_values("Total Count",ascending=False).reset_index().drop("index",axis = 1)
cityy_name
# Out:
#             City  Total Count
# 0      New Delhi         5473
# 1        Gurgaon         1118
# 2          Noida         1080
# 3      Faridabad          251
# 4      Ghaziabad           25
# ..           ...          ...
# 136  Dicky Beach            1
# 137         Lorn            1
# 138  Quezon City            1
# 139      Lincoln            1
# 140     Lakeview            1
#
# [141 rows x 2 columns]

# %% [raw]
# After re-ordering the index extra "index" column has been created because of "reset_index()" method so that "index" column is of no use and should be deleted using "drop" method.

# %%
dff.groupby(['City']).size().reset_index().rename(columns={0:"Total Count"}).sort_values("Total Count",ascending=False).reset_index().drop("index",axis = 1).head()
# Out:
#         City  Total Count
# 0  New Delhi         5473
# 1    Gurgaon         1118
# 2      Noida         1080
# 3  Faridabad          251
# 4  Ghaziabad           25

# %%
dff.groupby(['City']).size().reset_index().rename(columns={0:"Total Count"}).sort_values("Total Count",ascending=False)[:5].reset_index().drop("index",axis = 1)
# Out:
#         City  Total Count
# 0  New Delhi         5473
# 1    Gurgaon         1118
# 2      Noida         1080
# 3  Faridabad          251
# 4  Ghaziabad           25

# %%
#testing code

cityy_name.head().values
# Out:
# array([['New Delhi', 5473],
#        ['Gurgaon', 1118],
#        ['Noida', 1080],
#        ['Faridabad', 251],
#        ['Ghaziabad', 25]], dtype=object)

# %%
ll = []
for x in cityy_name['City'].head():
    ll.append(x)
ll
# Out:
# ['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad']

# %%
list1 = []
for i in range(5):
    list1.append(cityy_name.values[i][0])
list1
# Out:
# ['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad']

# %%
ll1 = []
for x in cityy_name["Total Count"].head():
    ll1.append(x)
ll1
# Out:
# [5473, 1118, 1080, 251, 25]

# %%
list2 = []
for i in range(5):
    list2.append(cityy_name.values[i][1])
list2
# Out:
# [5473, 1118, 1080, 251, 25]

# %%
plt.pie(list2,labels = list1,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d834db6f50>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %%
City = dff[['City']].value_counts().reset_index().rename(columns={0:"Total Count"})
City
# Out:
#             City  Total Count
# 0      New Delhi         5473
# 1        Gurgaon         1118
# 2          Noida         1080
# 3      Faridabad          251
# 4      Ghaziabad           25
# ..           ...          ...
# 136  Dicky Beach            1
# 137         Lorn            1
# 138  Quezon City            1
# 139      Lincoln            1
# 140     Lakeview            1
#
# [141 rows x 2 columns]

# %% [raw]
# The above method display the data in descending order by "value(Total Count)" not by "groups(City)".

# %%
City = dff[['City']].value_counts().reset_index().rename(columns={0:"Total Count"}).head()
City
# Out:
#         City  Total Count
# 0  New Delhi         5473
# 1    Gurgaon         1118
# 2      Noida         1080
# 3  Faridabad          251
# 4  Ghaziabad           25

# %%
City = dff[['City']].value_counts()[:5].reset_index().rename(columns={0:"Total Count"})
City
# Out:
#         City  Total Count
# 0  New Delhi         5473
# 1    Gurgaon         1118
# 2      Noida         1080
# 3  Faridabad          251
# 4  Ghaziabad           25

# %%
city_name1 = City.head().City
city_name1
# Out:
# 0    New Delhi
# 1      Gurgaon
# 2        Noida
# 3    Faridabad
# 4    Ghaziabad
# Name: City, dtype: object

# %%
city_name = dff.City.value_counts().head().index
city_name
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad'], dtype='object')

# %%
city_name_count1 = City.head()['Total Count']
city_name_count1
# Out:
# 0    5473
# 1    1118
# 2    1080
# 3     251
# 4      25
# Name: Total Count, dtype: int64

# %%
city_name_count = dff.City.value_counts().head().values
city_name_count
# Out:
# array([5473, 1118, 1080,  251,   25], dtype=int64)

# %%
plt.pie(city_name_count,labels = city_name1,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d834e2ba10>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [raw]
# Mostly Zomato users are from Indian cities like 'New Delhi','Gurgaon','Noida','Faridabad', and 'Ghaziabad'.

# %% [markdown]
# # Find out the top 11 Cuisines

# %%
dff.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
cuisines = dff.groupby(['Cuisines']).size().reset_index().rename(columns={0:"Total Counts"}).sort_values('Total Counts',ascending=False).reset_index().drop("index",axis = 1)
cuisines
# Out:
#                                                Cuisines  Total Counts
# 0                                          North Indian           936
# 1                                 North Indian, Chinese           511
# 2                                               Chinese           354
# 3                                             Fast Food           354
# 4                                 North Indian, Mughlai           334
# ...                                                 ...           ...
# 1820  Continental, Italian, North Indian, Lebanese, ...             1
# 1821       Continental, Italian, North Indian, Lebanese             1
# 1822  Continental, Italian, North Indian, Chinese, L...             1
# 1823        Continental, Italian, North Indian, Chinese             1
# 1824                    World Cuisine, Patisserie, Cafe             1
#
# [1825 rows x 2 columns]

# %% [raw]
# 1) Firstly, the datas is sorted in asceding order by "Group(City)" not by "value(Total Count)".
# 2) Then, the datas is again sorted  in descending order by "Total Count" column.
# 3) So, again "reset_index()" method is used to re-order the index because sorting the dataset results in alter in the index.
# 4) After re-ordering the index extra "index" column has been created because of "reset_index()" method so that "index" column is of no use and should be deleted using "drop" method.

# %%
dff.groupby(['Cuisines']).size().reset_index().rename(columns={0:"Total Counts"}).sort_values('Total Counts',ascending=False).reset_index().drop("index",axis = 1).head(11)
# Out:
#                           Cuisines  Total Counts
# 0                     North Indian           936
# 1            North Indian, Chinese           511
# 2                          Chinese           354
# 3                        Fast Food           354
# 4            North Indian, Mughlai           334
# 5                             Cafe           299
# 6                           Bakery           218
# 7   North Indian, Mughlai, Chinese           197
# 8                 Bakery, Desserts           170
# 9                      Street Food           149
# 10                Pizza, Fast Food           131

# %%
dff.groupby(['Cuisines']).size().reset_index().rename(columns={0:"Total Counts"}).sort_values('Total Counts',ascending=False)[:11].reset_index().drop("index",axis = 1)
# Out:
#                           Cuisines  Total Counts
# 0                     North Indian           936
# 1            North Indian, Chinese           511
# 2                          Chinese           354
# 3                        Fast Food           354
# 4            North Indian, Mughlai           334
# 5                             Cafe           299
# 6                           Bakery           218
# 7   North Indian, Mughlai, Chinese           197
# 8                 Bakery, Desserts           170
# 9                      Street Food           149
# 10                Pizza, Fast Food           131

# %%
cus_list_name = []
for i in range(11):
    cus_list_name.append(cuisines.values[i][0])
cus_list_name
# Out:
# ['North Indian',
#  'North Indian, Chinese',
#  'Chinese',
#  'Fast Food',
#  'North Indian, Mughlai',
#  'Cafe',
#  'Bakery',
#  'North Indian, Mughlai, Chinese',
#  'Bakery, Desserts',
#  'Street Food',
#  'Pizza, Fast Food']

# %%
cus_list1_name = []
for i in cuisines.Cuisines.head(11):
    cus_list1_name.append(i)
cus_list1_name
# Out:
# ['North Indian',
#  'North Indian, Chinese',
#  'Chinese',
#  'Fast Food',
#  'North Indian, Mughlai',
#  'Cafe',
#  'Bakery',
#  'North Indian, Mughlai, Chinese',
#  'Bakery, Desserts',
#  'Street Food',
#  'Pizza, Fast Food']

# %%
cus_list_count = []
for i in range(11):
    cus_list_count.append(cuisines.values[i][1])
cus_list_count
# Out:
# [936, 511, 354, 354, 334, 299, 218, 197, 170, 149, 131]

# %%
cus_list1_count = []
for i in cuisines['Total Counts'][:11]:
    cus_list1_count.append(i)
cus_list1_count
# Out:
# [936, 511, 354, 354, 334, 299, 218, 197, 170, 149, 131]

# %%
plt.pie(cus_list1_count, labels = cus_list_name ,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d834e3ac50>,
# ...
#  [Text(0.7624514950536498, 0.7928856901788898, 'North Indian'),
#   Text(-0.5065827546470452, 0.9764086811853998, 'North Indian, Chinese'),
#   Text(-1.0339491875430904, 0.3754318547739167, 'Chinese'),
#   Text(-1.06286447441522, -0.2834062614446936, 'Fast Food'),
#   Text(-0.7241090537387509, -0.8280495627035684, 'North Indian, Mughlai'),
#   Text(-0.19059887814920093, -1.0833614667544098, 'Cafe'),
#   Text(0.2939040269060523, -1.0600096334318885, 'Bakery'),
#   Text(0.6457216710461804, -0.8905299116488613, 'North Indian, Mughlai, Chinese'),
#   Text(0.890252241854364, -0.6461044388280266, 'Bakery, Desserts'),
#   Text(1.031998214639219, -0.38076197943264356, 'Street Food'),
#   Text(1.0930265809954232, -0.1236644380469015, 'Pizza, Fast Food')],
#  [Text(0.4158826336656271, 0.43248310373393983, '25.62%'),
#   Text(-0.27631786617111553, 0.5325865533738544, '13.99%'),
#   Text(-0.5639722841144129, 0.20478101169486365, '9.69%'),
# ...

# %%
cuisines = dff[['Cuisines']].value_counts().reset_index().rename(columns={0:"Total Counts"})
cuisines
# Out:
#                                                Cuisines  Total Counts
# 0                                          North Indian           936
# 1                                 North Indian, Chinese           511
# 2                                               Chinese           354
# 3                                             Fast Food           354
# 4                                 North Indian, Mughlai           334
# ...                                                 ...           ...
# 1820  Continental, Italian, North Indian, Lebanese, ...             1
# 1821       Continental, Italian, North Indian, Lebanese             1
# 1822  Continental, Italian, North Indian, Chinese, L...             1
# 1823        Continental, Italian, North Indian, Chinese             1
# 1824                    World Cuisine, Patisserie, Cafe             1
#
# [1825 rows x 2 columns]

# %% [raw]
# The above method display the data in descending order by "value(Total Counts)" not by "group(cuisines)".

# %%
dff[['Cuisines']].value_counts().reset_index().rename(columns={0:"Total Counts"}).head(11)
# Out:
#                           Cuisines  Total Counts
# 0                     North Indian           936
# 1            North Indian, Chinese           511
# 2                          Chinese           354
# 3                        Fast Food           354
# 4            North Indian, Mughlai           334
# 5                             Cafe           299
# 6                           Bakery           218
# 7   North Indian, Mughlai, Chinese           197
# 8                 Bakery, Desserts           170
# 9                      Street Food           149
# 10                Pizza, Fast Food           131

# %%
dff[['Cuisines']].value_counts()[:11].reset_index().rename(columns={0:"Total Counts"})
# Out:
#                           Cuisines  Total Counts
# 0                     North Indian           936
# 1            North Indian, Chinese           511
# 2                          Chinese           354
# 3                        Fast Food           354
# 4            North Indian, Mughlai           334
# 5                             Cafe           299
# 6                           Bakery           218
# 7   North Indian, Mughlai, Chinese           197
# 8                 Bakery, Desserts           170
# 9                      Street Food           149
# 10                Pizza, Fast Food           131

# %%
cuisines_name =  dff['Cuisines'].value_counts().head(11).index
cuisines_name
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#        'Pizza, Fast Food'],
#       dtype='object')

# %%
cuisines_name1 =  cuisines.Cuisines[:11]
cuisines_name1
# Out:
# 0                       North Indian
# 1              North Indian, Chinese
# 2                            Chinese
# 3                          Fast Food
# 4              North Indian, Mughlai
# 5                               Cafe
# 6                             Bakery
# 7     North Indian, Mughlai, Chinese
# 8                   Bakery, Desserts
# 9                        Street Food
# 10                  Pizza, Fast Food
# Name: Cuisines, dtype: object

# %%
cuisines_value_count =  dff['Cuisines'].value_counts()[:11].values
cuisines_value_count
# Out:
# array([936, 511, 354, 354, 334, 299, 218, 197, 170, 149, 131], dtype=int64)

# %%
cuisines_value_count1 =  cuisines['Total Counts'].head(11)
cuisines_value_count1
# Out:
# 0     936
# 1     511
# 2     354
# 3     354
# 4     334
# 5     299
# 6     218
# 7     197
# 8     170
# 9     149
# 10    131
# Name: Total Counts, dtype: int64

# %%
plt.pie(cuisines_value_count1,labels = cuisines_name,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d83502a250>,
# ...
#  [Text(0.7624514950536498, 0.7928856901788898, 'North Indian'),
#   Text(-0.5065827546470452, 0.9764086811853998, 'North Indian, Chinese'),
#   Text(-1.0339491875430904, 0.3754318547739167, 'Chinese'),
#   Text(-1.06286447441522, -0.2834062614446936, 'Fast Food'),
#   Text(-0.7241090537387509, -0.8280495627035684, 'North Indian, Mughlai'),
#   Text(-0.19059887814920093, -1.0833614667544098, 'Cafe'),
#   Text(0.2939040269060523, -1.0600096334318885, 'Bakery'),
#   Text(0.6457216710461804, -0.8905299116488613, 'North Indian, Mughlai, Chinese'),
#   Text(0.890252241854364, -0.6461044388280266, 'Bakery, Desserts'),
#   Text(1.031998214639219, -0.38076197943264356, 'Street Food'),
#   Text(1.0930265809954232, -0.1236644380469015, 'Pizza, Fast Food')],
#  [Text(0.4158826336656271, 0.43248310373393983, '25.62%'),
#   Text(-0.27631786617111553, 0.5325865533738544, '13.99%'),
#   Text(-0.5639722841144129, 0.20478101169486365, '9.69%'),
# ...

# %% [raw]
# Zomato user mostly orders Cuisines(Types of Foods) like 'North Indian', 'Chinese', 'Fast Food', 'North Indian, Mughlai' etc.
